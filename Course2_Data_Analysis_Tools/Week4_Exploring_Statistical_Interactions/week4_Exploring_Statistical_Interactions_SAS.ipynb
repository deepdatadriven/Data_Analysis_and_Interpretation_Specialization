# %% [markdown]
# # Statistical Interaction:
# It describes a relationship between two variables that is dependent upon or moderated by, a third variable/Moderator.<br>
# The effact of the moderating variable is often characterized statistically as an interaction, that is, **a third variable that effects the direction and/or strength of the relation between your explanatory and response variable.**
# ![image.png](attachment:image.png)

# %% [markdown]
# # ANOVA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Before I add a moderator, the original ANOVA result shows as Table 1. With the p-value < .0001 and F-value = 55.84, we can know the "headache level" and "time skip school" are significantelly associated. The mean values shown in Table 2, which are 11.79 (0) < 17.99 (1), it tells that the adolescents who are often have a headache skip school more times than the adolescents who are not often have a headache.
#
# In order to testing a moderation by using ANOVA, I choose H1ED9, a categorical variable as my moderator (0-NO, 1-YES), which is "Have you ever been expelled from school?" (Section 5, Question 9).
#
# 1. By looking at the Table 3, the ANOVA table examing the relationship between "headache level" and "times skip school" for those in the "not expelled from school" group shows a large F-value 48.31 and a significant associated p-value < .0001. When examing the means table (Table 4), we see that for those who are not expelled from school, also often have a headache is associated with greater skip school times 17.15 on average, than the adolescents who are not often have a headache which is 11.44 time on average.
#
# 2. By looking at the Table 5, the ANOVA table examing the relationship between "headache level" and "times skip school" for those in the "expelled from school" group shows a small F-value 7.88 and a not significant associated p-value < 0.0054. It tells that for those who are expelled from school, there is no relationship between "headache level" and "times skip school".
#
# Based on the analysis we did above, we can conclude that H1ED9 has a significant moderation effect on the relationship between "headache level" and "times skip school".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Chi-Square

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Before I add a moderator, the original Chi-Square result shows as Table 6. With the p-value < .0001, we can know the "headache level" and "time skip school" are significantelly associated.
#
# In order to testing a moderation by using Chi-Square, I choose H1ED9, a categorical variable as my moderator (0-NO, 1-YES), which is "Have you ever been expelled from school?" (Section 5, Question 9).
#
# 1. By looking at the Table 7, for those "not expelled from school" which is 0, the chi-square value is large 6.7923 and the p-value < .0001 is quite small. It tells that the relationship between "headache level" and "time skip school" is statistically significant for those "not expelled from school".
#
# 2. By looking at the Table 8, for those "expelled from school" which is 1, the chi-square value is large 29.954 and the p-value = 0.1473 is large than 0.05. It tells that the relationship between "headache level" and "time skip school" is not statistically significant for those "expelled from school".
#
# Based on the analysis we did above, we can conclude that H1ED9 has a significant moderation effect on the relationship between "headache level" and "times skip school".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pearson Correlation Coefficient

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Before I add a moderator, the original Pearson Correlation Coefficient result shows as Table 9. With the r = 0.24961 and p-value <.0001(Table 2), it tells us the relationship between “number of cigarettes smoked each day” and “numbers of drinks had each time” are significantelly associated and weakly positive.
#
# In order to test a moderation using Pearson Correlation Coefficient, I choose H1ED9, a categorical variable as my moderator (0-NO, 1-YES), which is "Have you ever been expelled from school?" (Section 5, Question 9).
#
# 1. By looking at the Table 10, for those "not expelled from school" which is 0, the r value is 0.21577 and the p-value = .0002 is quite small. It tells that the relationship between “number of cigarettes smoked each day” and “numbers of drinks had each time” is statistically significant for those "not expelled from school".
#
# 2. By looking at the Table 11, for those "expelled from school" which is 1, the r value is large 0.32572 and the p-value = 0.1121 is large than 0.05. It tells that the relationship between “number of cigarettes smoked each day” and “numbers of drinks had each time” is not statistically significant for those "expelled from school".
#
# Based on the analysis we did above, we can conclude that H1ED9 has a significant moderation effect on the relationship between “number of cigarettes smoked each day” and “numbers of drinks had each time”.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
